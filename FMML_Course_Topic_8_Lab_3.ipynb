# %% [markdown]
# <a href="https://colab.research.google.com/github/maryprameelaguthula/fmml_project_and_labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 15:51:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  90.0MB/s    in 0.8s
#
# 2024-04-05 15:51:08 (90.0 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 38529   0908.4310v2  One of the most important tasks in image proce...  stat
# 37934   1204.0585v4  This paper studies iteration convergence of Kr...  stat
# 10691   1212.0388v1  Most network-based protein (or gene) function ...  stat
# 11332  1510.03349v2  The leaderboard in machine learning competitio...  stat
# 22271  1511.03249v3  A method for large scale Gaussian process clas...  stat
# ...             ...                                                ...   ...
# 23920   1303.4839v1  Handwriting recognition refers to the identifi...    cs
# 19433   0909.4446v1  Fuzzy constraints are a popular approach to ha...    cs
# 12366  1712.07897v1  A vast majority of machine learning algorithms...  stat
# 28004  1705.03212v1  The primary contribution of this paper is an e...    cs
# 39899  1707.03720v1  Vision sensors lie in the heart of computer vi...    cs
#
#                                                    title  year  \
# 38529  Co-occurrence Matrix and Fractal Dimension for...  2009
# 37934  Convergence Properties of Kronecker Graphical ...  2012
# 10691  Hypergraph and protein function prediction wit...  2012
# 11332       Toward a Better Understanding of Leaderboard  2015
# 22271  Stochastic Expectation Propagation for Large S...  2015
# ...                                                  ...   ...
# 23920  The State of the Art Recognize in Arabic Scrip...  2013
# 19433  Elicitation strategies for fuzzy constraint pr...  2009
# 12366       Non-convex Optimization for Machine Learning  2017
# 28004  Efficient Structure from Motion for Oblique UA...  2017
# 39899  Multiband NFC for High-Throughput Wireless Com...  2017
#
#                                                 keywords
# 38529  [important, processing, recognition, algorithm...
# 37934  [iteration, convergence, kronecker, graphical,...
# 10691  [prediction, assumption, relationship, informa...
# 11332  [leaderboard, competitions, performance, parti...
# 22271  [classification, expectation, propagation, cla...
# ...                                                  ...
# 23920  [handwriting, recognition, identification, cha...
# 19433  [constraints, preferences, constrained, scenar...
# 12366  [algorithms, inference, optimization, predicti...
# 28004  [contribution, efficient, structure, algorithm...
# 39899  [applications, contacting, communication, thro...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 38529    [important, processing, recognition, algorithm...
# 37934    [iteration, convergence, kronecker, graphical,...
# 10691    [prediction, assumption, relationship, informa...
# 11332    [leaderboard, competitions, performance, parti...
# 22271    [classification, expectation, propagation, cla...
#                                ...
# 5470     [parallelizable, algorithm, partitioning, algo...
# 6793     [framework, backpropagation, substantially, de...
# 6924     [diffusion, similarity, metametrics, specifica...
# 30982    [framework, alignment, estimation, attribute, ...
# 2749     [generalization, reinforcement, especially, in...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8719 words.
# Out of those 4587 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="450c4dc2-9069-4ae6-abde-c25b8f316483" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("450c4dc2-9069-4ae6-abde-c25b8f316483")) {                    Plotly.newPlot(                        "450c4dc2-9069-4ae6-abde-c25b8f316483",                        [{"x":["algorithm","illustrate","comparative","operators","occurrence","recognition","dimension","important","introduced","processing","segmentation","multivariate","dimensional","imputation","kronecker","likelihood","structure","simulations","significantly","asymptotic","application","penalties","iteration","transposable","estimation","implements","covariances","covariance","generalizes","originally","convergence","selection","estimator","algorithms","graphical","penalized","distribution","estimating","variables","pointwise","presented","regularized","establish","properties","hypergraph","normalized","overcoming","prediction","functional","performance","laplacian","constructed","symmetric","information","experiment","functions","supervised","relationship","assumption","represent","expression","participants","complexity","competitions","following","understanding","eliminating","precision","redundant","overfitting","parameter","computation","leaderboard","inevitable","interpret","conclusion","something","naturally","deployments","limitation","competitive","variational","resources","expectation","inference","classifiers","nevertheless","propagation","techniques","stochastic","classification","instances","summarization","informative","established","evaluation","particular","dynamical","measurements","represented","extractive","differently","relevance","accessibility","characterization","sentences","absorption","paramount","documents","available","exploration","identification","excellent","including","regression","orientation","concentrate","potential","correlated","eigenvalues","artifacts","association","detecting","coefficients","confounding","challenging","different","extracted","interpolations","interpolation","paintings","unordered","difficult","characteristics","experiments","photographs","collections","photograph","predictions","promising","developed","stylistic","practical","influence","applications","suggestion","conducted","recolorization","digitized","quantitative","meaningful","conventional","frequently","favorable","collected","statistical","consequently","perceptions","grounding","notoriously","automatic","approaches","principled","companies","scientific","framework","attracting","prominent","pertaining","experimental","availability","generated","improving","efficiency","capturing","flexibility","validation","searching","introducing","community","analytics","implement","extensions","component","cornerstone","multidimensional","groundwork","empirical","furthermore","decomposition","nonnegative","researchers","centering","simulated","designing","eigenvectors","providing","principal","counterpart","theoretic"],"y":[811,80,32,43,22,384,70,363,122,297,207,29,199,3,2,59,343,41,268,21,229,5,43,0,206,13,3,24,26,15,105,143,25,614,51,4,194,63,118,4,168,31,51,216,3,26,9,202,40,890,15,68,21,731,75,226,223,78,73,108,74,22,221,7,82,168,5,77,14,21,101,140,2,7,21,17,8,44,1,23,107,60,80,30,203,112,17,69,413,135,501,94,29,44,38,277,276,24,63,86,8,7,38,3,23,50,4,3,58,315,69,113,31,271,122,27,5,127,32,3,26,29,72,31,5,300,730,121,1,16,4,3,156,77,645,8,16,3,94,129,185,2,131,71,413,3,84,2,6,78,44,114,33,4,66,150,31,5,12,7,181,421,24,8,31,532,12,13,5,396,20,175,125,132,38,40,53,37,64,71,14,59,42,103,3,19,1,140,163,63,7,73,1,61,51,10,88,39,13,42],"type":"bar"},{"x":["algorithm","illustrate","comparative","operators","occurrence","recognition","dimension","important","introduced","processin ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4587,), (4587, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Topology</span> <span style=''>Adaptive</span> <span style=''>Graph</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Convolutional</span> <span style=''>Networks</span> <br/><br/><span style=''>Spectral</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(CNNs)</span> <span style=''>require</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5692307692307692);'>convolution</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>alleviate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>loss</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>the</span> <span style=''>topology</span> <span style=''>adaptive</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>convolutional</span> <span style=''>network</span> <span style=''>(TAGCN)</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>convolutional</span> <span style=''>network</span> <span style=''>defined</span> <span style=''>in</span> <span style=''>the</span> <span style=''>vertex</span> <span style=''>domain</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematic</span> <span style=''>way</span> <span style=''>to</span> <span style=''>design</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>fixed</span> <span style=''>size</span> <span style='background-color:rgba(0, 255, 0, 0.30434782608695654);'>learnable</span> <span style=''>filters</span> <span style=''>to</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>convolutions</span> <span style=''>on</span> <span style=''>graphs</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>topologies</span> <span style=''>of</span> <span style=''>these</span> <span style=''>filters</span> <span style=''>are</span> <span style=''>adaptive</span> <span style=''>to</span> <span style=''>the</span> <span style=''>topology</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>when</span> <span style=''>they</span> <span style=''>scan</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>to</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.5692307692307692);'>convolution</span> <span style=''>The</span> <span style=''>TAGCN</span> <span style=''>not</span> <span style=''>only</span> <span style=''>inherits</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>convolutions</span> <span style=''>in</span> <span style=''>CNN</span> <span style=''>for</span> <span style=''>grid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>data</span> <span style=''>but</span> <span style=''>it</span> <span style=''>is</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>with</span> <span style='background-color:rgba(0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>Using</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>for</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>It</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>querying</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relatively</span> <span style=''>cheap</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogate</span> <span style=''>model</span> <span style=''>An</span> <span style=''>accurate</span> <span style=''>model</span> <span style=''>for</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>is</span> <span style=''>critical</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>approach</span> <span style=''>and</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>fit</span> <span style=''>using</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(GPs)</span> <span style=''>However</span> <span style=''>since</span> <span style=''>GPs</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cubically</span> <span style=''>with</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>it</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>to</span> <span style=''>handle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>requires</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>and</span> <span style=''>as</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>massively</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parallelizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternati ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>Coding</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Concept</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.39512195121951216);'>Similarity</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>develops</span> <span style=''>a</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>coding</span> <span style=''>which</span> <span style=''>combines</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3211009174311927);'>geometric</span> <span style=''>model</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695654);'>principled</span> <span style=''>way</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3211009174311927);'>geometric</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>manifold</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>metric</span> <span style=''>g</span> <span style=''>ij(bf</span> <span style=''>x)</span> <span style=''>which</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpret</span> <span style=''>as</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dissimilarity</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3316831683168317);'>stochastic</span> <span style=''>process</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>measure</span> <span style=''>which</span> <span style=''>matches</span> <span style=''>the</span> <span style=''>density</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>input</span> <span style=''>data</span> <span style=''>The</span> <span style=''>link</span> <span style=''>between</span> <span style=''>the</span> <span style=''>two</span> <span style=''>models</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>function</span> <span style=''>U(bf</span> <span style=''>x)</span> <span style=''>and</span> <span style=''>its</span> <span style=''>gradient</span> <span style=''>nabla</span> <span style=''>U(bf</span> <span style=''>x)</span> <span style=''>We</span> <span style=''>use</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>to</span> <span style=''>define</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dissimilarity</span> <span style=''>metric</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>that</span> <span style=''>our</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dissimilarity</span> <span style=''>will</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>for</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>analysis</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>images</span> <br/><br/><span style=''>The</span> <span style=''>use</span> <span style=''>of</span> <span style=''>brain</span> <span style=''>images</span> <span style=''>as</span> <span style=''>markers</span> <span style=''>for</span> <span style=''>diseases</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>behavioral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenged</span> <span style=''>by</span> <span style=''>the</span> <span style=''>small</span> <span style=''>effects</span> <span style=''>size</span> <span style=''>and</span> <span style=''>the</span> <span style=''>ensuing</span> <span style=''>lack</span> <span style=''>of</span> <span style=''>power</span> <span style=''>an</span> <span style=''>issue</span> <span style=''>that</span> <span style=''>has</span> <span style=''>incited</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>to</span> <span style=''>rely</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematically</span> <span style=''>on</span> <span style=''>large</span> <span style=''>cohorts</span> <span style=''>Coupled</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increases</span> <span style=''>this</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>very</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>A</span> <span style=''>striking</span> <span style=''>example</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>brain</span> <span style=''>imaging</span> <span style=''>is</span> <span style=''>that</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Human</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Connectome</span> <span style=''>Project</span> <span style=''>20</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Terabytes</span> <span style=''>of</span> <span style=''>data</span> <span style=''>and</span> <span style=''>growing</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>data</span> <span style=''>deluge</span> <span style=''>poses</span> <span style=''>severe</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractability</span> <span style=''>of</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>steps</span> <span style=''>(discriminant</span> <span style=''>analysis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>models)</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>memory</span> <span style=''>demands</span> <span style=''>posed</span> <span style=''>by</span> <span style=''>these</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>revisit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style='backgrou ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.140625)
# 	knowledge (0.12819602272727273)
# 	evaluation (0.09836647727272728)
# 	challenging (0.10653409090909091)
# 	segmentation (0.07350852272727272)
# 	detection (0.12180397727272728)
# 	different (0.25923295454545453)
# 	information (0.2595880681818182)
# 	convolutional (0.13494318181818182)
# 	recognition (0.13636363636363635)
#
# Some Statistics words are:
# 	theoretical (0.14415322580645162)
# 	stochastic (0.13558467741935484)
# 	algorithm (0.37701612903225806)
# 	variables (0.13205645161290322)
# 	statistical (0.1507056451612903)
# 	estimation (0.17842741935483872)
# 	distribution (0.18598790322580644)
# 	dimensional (0.1905241935483871)
# 	inference (0.20262096774193547)
# 	regression (0.17641129032258066)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0455a5e8-dda9-4413-8a9d-4ca88c1c2b84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0455a5e8-dda9-4413-8a9d-4ca88c1c2b84")) {                    Plotly.newPlot(                        "0455a5e8-dda9-4413-8a9d-4ca88c1c2b84",                        [{"x":["algorithm","illustrate","comparative","operators","occurrence","recognition","dimension","important","introduced","processing","segmentation","multivariate","dimensional","imputation","kronecker","likelihood","structure","simulations","significantly","asymptotic","application","penalties","iteration","transposable","estimation","implements","covariances","covariance","generalizes","originally","convergence","selection","estimator","algorithms","graphical","penalized","distribution","estimating","variables","pointwise","presented","regularized","establish","properties","hypergraph","normalized","overcoming","prediction","functional","performance","laplacian","constructed","symmetric","information","experiment","functions","supervised","relationship","assumption","represent","expression","participants","complexity","competitions","following","understanding","eliminating","precision","redundant","overfitting","parameter","computation","leaderboard","inevitable","interpret","conclusion","something","naturally","deployments","limitation","competitive","variational","resources","expectation","inference","classifiers","nevertheless","propagation","techniques","stochastic","classification","instances","summarization","informative","established","evaluation","particular","dynamical","measurements","represented","extractive","differently","relevance","accessibility","characterization","sentences","absorption","paramount","documents","available","exploration","identification","excellent","including","regression","orientation","concentrate","potential","correlated","eigenvalues","artifacts","association","detecting","coefficients","confounding","challenging","different","extracted","interpolations","interpolation","paintings","unordered","difficult","characteristics","experiments","photographs","collections","photograph","predictions","promising","developed","stylistic","practical","influence","applications","suggestion","conducted","recolorization","digitized","quantitative","meaningful","conventional","frequently","favorable","collected","statistical","consequently","perceptions","grounding","notoriously","automatic","approaches","principled","companies","scientific","framework","attracting","prominent","pertaining","experimental","availability","generated","improving","efficiency","capturing","flexibility","validation","searching","introducing","community","analytics","implement","extensions","component","cornerstone","multidimensional","groundwork","empirical","furthermore","decomposition","nonnegative","researchers","centering","simulated","designing","eigenvectors","providing","principal","counterpart","theoretic","connecting","correlation","factorization","viewpoints","canonical","discriminant","constructing","outperforms","continued","denoising","clustering","dictionary","traditional","questions","optimization","considered","obtaining","exploited","contaminated","sequences","predetermined","scenarios","discrepancy","evaluated","introduce","configuration","significant","hyperparameter","diversity","parallelizable","efficient","metropolis","distributions","processes","independently","dimensions","continuous","transforms","realistic","determinantal","gradients","completely","technique","computational","knowledge","frameworks","facilitate","activation","localization","evaluating","magnitude","proposals","generating","supervision","annotations","localisation","possesses","inc ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	transposable
# 	archetypes
# 	transformative
# 	stabilisation
# 	penalization
# 	enclosing
# 	ellipsoid
# 	precludes
# 	homoscedastic
# 	frequentist
# 	heteroscedastic
# 	metabolic
# 	electrocardiograms
# 	interpolating
# 	convincingly
# 	invertible
# 	disclosed
# 	proprietary
# 	oscillations
# 	fmathcalx
# Some words which never appear in Statistics papers:
# 	extractive
# 	accessibility
# 	absorption
# 	photographs
# 	photograph
# 	stylistic
# 	recolorization
# 	digitized
# 	continued
# 	reflection
# 	validates
# 	diversifying
# 	treewidth
# 	treewidths
# 	delineate
# 	vehicular
# 	localizing
# 	illumination
# 	suppression
# 	transmitted

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.053714844107858e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
